# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.stats import norm,beta,multivariate_normal
# %matplotlib inline
#%matplotlib nbagg

x = np.arange(-2,2,0.1)
y = np.arange(-2,2,0.1)

X, Y = np.meshgrid(x, y)
Z = norm.pdf(X,loc=1.8,scale=0.2) * norm.pdf(Y,loc=1.8,scale=0.2) \
    + norm.pdf(X,loc=1.8, scale=0.2) * norm.pdf(Y,loc=-1.8,scale=0.2) \
    + norm.pdf(X,loc=-1.8,scale=0.2) * norm.pdf(Y,loc=1.8,scale=0.2) \
    + norm.pdf(X,loc=-1.8,scale=0.2) * norm.pdf(Y,loc=-1.8,scale=0.2) \
    - norm.pdf(Y,loc=1.8, scale=0.2) * beta.pdf(x, a=1, b=1, loc=-1.25,scale=2.5)*5

fig = plt.figure(figsize=(4,6))
ax = fig.add_subplot(111, projection='3d')
ax.set_aspect(1.8)
#ax.scatter3D(X,Y,-Z,'r.')
ax.plot_wireframe(X,Y,-Z)
#ax.plot_surface(X,Y,-Z,color='r')
plt.show()

# %%
N = 100
x1 = np.linspace(-5, 5, N)
x2 = np.linspace(-5, 5, N)

X1, X2 = np.meshgrid(x1, x2)
X = np.c_[np.ravel(X1), np.ravel(X2)]

Y_plot = norm.pdf(x=X, loc=np.zeros(2), scale=np.eye(2))
Y_plot = Y_plot.reshape(X1.shape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X1, X2, Y_plot, cmap='bwr', linewidth=0)
fig.colorbar(surf)
ax.set_title("Surface Plot")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b6528839d1c7> in <module>()
#       6 X = np.c_[np.ravel(X1), np.ravel(X2)]
#       7
# ----> 8 Y_plot = norm.pdf(x=X, loc=np.zeros(2,2), scale=np.eye(2,2))
#       9 Y_plot = Y_plot.reshape(X1.shape)
#      10
#
# TypeError: data type not understood

# %%
from scipy.stats import beta, gamma
# %matplotlib inline

# %%
x = np.linspace(-2,2, 100)
a, b = 0.99, 0.99
y = beta.pdf(x, a=0.99, b=0.99, loc=-1,scale=2)
y1 = gamma.pdf(x,a=0.5,loc=0,scale=0.2)
plt.plot(x, y, 'r-')
#plt.plot(x, y1, 'b-')
