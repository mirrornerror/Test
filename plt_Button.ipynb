# %%
# %matplotlib notebook
from matplotlib.widgets import Button
import matplotlib.pyplot as plt
def callback(event):
    plt.text(event.xdata, event.ydata, 'clicked\n'+ 'x:'+str(event.xdata) + '\ny:' +str(event.ydata))

f,a = plt.subplots(1)
b1 = Button(a,'Button1')
b1.on_clicked(callback)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib.widgets import Button
import matplotlib.pyplot as plt
def callback(event):
    plt.text(event.xdata, event.ydata, 'clicked\n'+ 'x:'+str(event.xdata) + '\ny:' +str(event.ydata))
    print(event.xdata)
    
    
    

fig = plt.figure()
ax1 = plt.subplot(121)
b1 = Button(ax1,'Button1', color='gray')
b1.on_clicked(callback)

ax2 = plt.subplot(122)
b2 = Button(ax2,'Button2', color='gray')
b2.on_clicked(callback)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
from matplotlib.widgets import Button
import matplotlib.pyplot as plt

def callback(event):
    #plt.text(event.xdata, event.ydata, 'clicked\n'+ 'x:'+str(event.xdata) + '\ny:' +str(event.ydata))
    global flag
    flag = not flag
    if flag:
        b1.color='#ff0000'
        b1.hovercolor='#ff6666'
    else:
        b1.color='#cccccc'
        b1.hovercolor='#dddddd'

flag = False
#fig, ax = plt.subplots()
plt.figure()
a1 = plt.axes([0, 0.5, 0.5, 0.5])
a2 = plt.axes([0.5, 0.5, 0.5, 0.5])
b1 = Button(a1,'Button1', color='#bbbbbb', hovercolor='#dddddd')
b1.on_clicked(callback)
# b2 = Button(a2,'Button2', color='#cccccc', hovercolor='#dddddd')
# b2.on_clicked(callback2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0

# %%
flag = False
not flag
# Out:
# True
