# %%
# %matplotlib inline
#%matplotlib nbagg
#%matplotlib ipympl
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# /home/mirrornerror/.pyenv/versions/anaconda3-5.1.0/envs/py36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.9.0

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import HTML

# %%
x = np.linspace(0,10,100)
y = np.sin(x)*x
fig = plt.figure(facecolor='#dddddd')
plt.axis('off')
#plt.plot(x,y)
ims = []
for i in range(len(x)):
    dl = plt.plot(x,y,'b--',alpha=0.3)
    ln = plt.plot(x[:i],y[:i], 'b-',linewidth=1, alpha=0.6)
    pt = plt.plot(x[i],y[i],'bo',markersize=4,linewidth=6)
    ims.append(dl + ln + pt)

ani = animation.ArtistAnimation(fig, ims, interval=50)
plt.close()
HTML(ani.to_jshtml())
#HTML(ani.to_html5_video())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img29238e81308a4a2b95fc880858af1fee">
#     <br>
#     <input id="_anim_slider29238e81308a4a2b95fc880858af1fee" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim29238e81308a4a2b95fc880858af1fee.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim29238e81308a4a2b95fc880858af1fee.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select29238e81308a4a2b95fc880858af1fee" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img29238e81308a4a2b95fc880858af1fee";
#     var slider_id = "_anim_slider29238e81308a4a2b95fc880858af1fee";
#     var loop_select_id = "_anim_loop_select29238e81308a4a2b95fc880858af1fee";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMS4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvNQv5yAAAGbpJREFUeJzt3Wl3U9fZxvFL8jxi2WCMDTY4GANh\
# KCQtNE9WmiZt+qofr58kL7vSJE2zSAmTEwYzGfAkT3jAsyTrPC/uatlJGGxZ0j77nP9vLS+VhqK7\
# jtF19t733jsRBEEgAAA8k3RdAAAAxSDAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABe\
# IsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLA\
# AABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAA\
# XiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4iwAAAXiLAAABeIsAAAF4i\
# wABE0uqqND8v5XKuK0G5VLsuAABKIZeTnjyRTpyQ6uqkdFp68EBKJKTmZunQIenUKammxnWlKBUC\
# DID3xsctrDY2pM5OC7Bjx6SWFmlx0b6ePbNQ++wzKcncUyQkgiAIXBcBAMXI5aQbN6TZWamtTTp3\
# TkqlXv97X72Slpelnh77dRDY6Az+IsAAeOv2bWliwoKrr2/3gTQ6Ko2NSVeuSNXMQ3mLAAPgrY0N\
# G1l1du7tfzc5Kd26JbW3W4hVVZWnPpQXM8EAvLK1JQ0P2xRgff3ew0uSurulS5ekly+lH3+0Pwv+\
# IcAAeOWnn6THj6Wlpf39OT090sWLtn72+HFpakNlMfsLwBujo9ZxeOqUNW3sV2+v7RWjmcNPrIEB\
# 8MLSkvSf/0gdHbZuReiAKUQAoRcE1nFYWytdvlye8JqZkR4+LP2fi/JhChFA6CUS0ocf2r6v2try\
# vMfsrDQyYid2tLeX5z1QWozAAIRaPm+vzc2lWfd6k9On7QSPBw/K9x4oLQIMQKhdvy4NDZX/faqq\
# pMFBa+qYmir/+2H/CDAAoTU5aVN7ra2Veb/eXhvpPXjA3jAfsAYGIJS2tqR796QDB6TjxyvznomE\
# HUu1uVmZ98P+EGAAQunZMzsq6oMPKtsyf+hQ5d4L+8MUIoDQCQLpxQs7JspFR2AQ2N1iExOVf2/s\
# HiMwAKGTSEiffCJls+7ef2pKymTs3EQ2TYcTIzAAoZLP2wiopkZqbHRXR3+/tLoqTU+7qwFvR4AB\
# CJVHj6Tvvtve/+XKkSNSQ4P09KnbOvBmBBiA0Mhk7DSMpiYp6fjTKZGwUdj8vLS46LYWvB5rYABC\
# 48ULa58/dcp1Jaa31+4MYw0snAgwAKGQz1vrfGen1NLiuhpTXS39/veuq8CbMIUIIBQmJ20DcX+/\
# 60p+a33dRmIIF0ZgAEKhu9vOIwzjRuKhIWllRfr8c6YTw4QRGIBQSCat8y+MenttFDY357oS7ESA\
# AXDuzh1pdNR1FW/W1WX70sbGXFeCnQgwAE69emXBkMm4ruTNkknp6FEpnXZ3Ogh+iwAD4NSLFxYQ\
# fX2uK3m7Y8fshJD5edeVoIAmDgDO5HLS+Lg1cNTUuK7m7Q4ckL74QqqtdV0JChiBAXBmctJCrFL3\
# fe0X4RUuBBgAZ5qaLLxSKdeV7E4QSNeuScPDriuBRIABcKijQzp/3nUVu5dI2Hod94SFAwEGwImp\
# Kdtb5ZvubmltjQN+w4AAA1Bx2ax065ZdneKbri4bhU1Ouq4EBBiAipuctFPnw946/zo1NdLBgwRY\
# GNBGD6DixsbsxPm2NteVFKe/385GzOfd31sWZwQYgIpaWZEWFqSzZ11XUrxDh8J56HDc8OwAoKIW\
# FraPZvJZNmubsIPAdSXxxQgMQEUdO2anzld7/ukzPS3dvm172XzZxxY1jMAAVExht
